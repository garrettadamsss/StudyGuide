# %%
name = input('Enter your name: ')
print('Hello, ' + name + '!')
print(type(name))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 name = input('Enter your name: ')
#       2 print('Hello, ' + name + '!')
#       3 print(type(name))
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ipykernel\kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ipykernel\kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
# ...

# %%
if -1: 
    print('This is a negative number')
elif 0:
    print('This is zero')
else: 
    print('This is a positive number')

# %%
x = 4
y = 3
x > 2 and y > 1      # returns True
x > 5 or y <= 3      # returns True
not(x > 2 and y > 1) # returns False

# %%
# for loop
nums = [3, 4, 16]

print('This is an example of for loops')

for num in nums:
    print(num ** 2)

# while loop
i = 3

print('This is an example of while loops')

while i < 258:
    print(i)
    i = i ** 2
    
# disrupt loops key words
names = ['Amanda', 'Mercedes', 'Rachel', 'Elisabeth', 'Tay', 'Xavier', 'Joaquin', 'Sam']
for name in names:
    if 'm' in name.lower():
        continue # skips the iteration
    elif 'r' in name.lower():
        pass # do nothing
    elif 'j' in name.lower():
        break # exit the loop 
    else:
        print(name)
# Out:
# This is an example of for loops
# 9
# 16
# 256
# This is an example of while loops
# 3
# 9
# 81
# Elisabeth
# Tay

# %%
nums = ['x', 'y', 'z']

try: 
    print(sum(nums))
except: 
    print('Unable to get the sum')
finally: 
    print('thanks for summing it up')
# Out:
# Unable to get the sum
# thanks for summing it up

# %%
# funcs
def addThreeNums(n1, n2, n3): 
    sum = n1 + n2 + n3
    return sum; 
print(addThreeNums(1,2,3))

#recursion
def factorial(num): 
    if(num == 1): 
        return 1
    else: 
        return num * factorial(num - 1)
print(factorial(3))

#lambda/anonymous funcs
#lambda [arguments]: [expression] 
squareNum = lambda x: x**2
print(squareNum(5))

#Mainly used with higher order funcs
numbers = [1, 2, 3]
squared = list(map(lambda x: x **2, numbers))
print(squared)
# Out:
# 6
# 6
# 25
# ...

# %%
#Classes


#Objects
