# %%
"""
Lists

Ordered, mutable, dynamic, collections

"""

list = [1, "apple", 3.4]
list.append(2)  # appends element to the end of the list
list.extend([1, 2]) # appends items from an iterable 

list.remove(1) # removes first occurance of a value
list.pop(i) # if provided an index it removes and returns the element at index i, else removes the last index
list.clear() # clears

list.reverse() # returns items in reverse order (done in place!)
list.sort() # sorts ( done in place!)
list.index() # returns the index of the first matched element

for item in list:
    print(item)

for i in range(len(list)): 
    print(list[i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 13
#       9 list.append(2)  # appends element to the end of the list
#      10 list.extend([1, 2]) # appends items from an iterable
#      11
#      12 list.remove(1) # removes first occurance of a value
# ---> 13 list.pop(i) # if provided an index it removes and returns the element at index i, else removes the last index
#      14 list.clear() # clears
#      15
#      16 list.reverse() # returns items in reverse order (done in place!)
#
# NameError: name 'i' is not defined

# %%
"""
Tuples

Ordered, immutable, collections, allow duplicates 
"""

tuple = (1, "apple", 3.4)

# %%
"""
Dictionaries(HASHMAP)

Unordered, mutable collections of key-value pairs
"""

dictionary = {"a": 1, "b": 2, "c": 3}

dictionary.keys() # ["a", "b", "c"]
dictionary.values() # [1, 2, 3]
dictionary.items() # [("a", 1), ("b", 2), ("c", 3)]

dictionary["d"] = 4 # adds a key value pair
dictionary.update({"a": 2,"e": 5}) # updates values and also adds new pairs

dictionary.pop('d') # removes a key pair with given key

# %%
"""
Sets

Unordered, mutable collections, unique

"""

set = {1, 2, 3, "apple"}

set.add(4) # adds an element
set.remove(1) # removes an element and returns key error if doesn't exist
set.discard(5) # removes an element but doesn't throw an error if it doesn't exist

set2 = {1, 2, 10}
set.union(set2) # returns the all unique elements from both sets
set.intersection(set2) # returns the intersection between two sets
set.difference(set2) # returns elements in set1 but not in set2
